# %% [markdown]
# # **Decentralized Digital Identity using Blockchain**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install Faker
# Out:
# Requirement already satisfied: Faker in /usr/local/lib/python3.12/dist-packages (40.1.2)

# %% [markdown]
# ## **High-Voume Data Generation Script**

# %%
import csv
from faker import Faker
import uuid

fake = Faker()
record_count = 20000

# File name for your research data
filename = "student_identity_records.csv"

print(f"Generating {record_count} records... Please wait.")

with open(filename, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)

    # Headers for your Research Dataset
    writer.writerow(["Student_ID", "DID_Address", "Full_Name", "Degree", "Graduation_Year", "Email"])

    for _ in range(record_count):
        student_id = str(uuid.uuid4())[:8] # Short unique ID
        wallet_address = fake.hexify(text='0x' + '^' * 40) # Mock Blockchain Address

        writer.writerow([
            student_id,
            f"did:ethr:{wallet_address}",
            fake.name(),
            "B.Sc. Information Technology",
            "2026",
            fake.ascii_free_email()
        ])

print(f"Successfully generated {record_count} records in {filename}!")
# Out:
# Generating 20000 records... Please wait.
# Successfully generated 20000 records in student_identity_records.csv!

# %%
import json

with open('/content/drive/MyDrive/student_data.json', 'r') as f:
    loaded_data = json.load(f)
students = loaded_data["students"]
hashes = loaded_data["hashes"]

print(f"✅ Loaded {len(students)} students + {len(hashes)} hashes")
print(f"First student: {students[0]}")
print(f"First hash:    {hashes[0][:20]}...")
# Out:
# ✅ Loaded 20000 students + 20000 hashes
# First student: 0xef913c0bb17d0f37d7fdd895b84283824dd444da
# First hash:    Qm19076634b8f9dd4649...

# %% [markdown]
# # **Solidity**

# %%
# !pip install web3 faker
# Out:
# Collecting web3
#   Downloading web3-7.14.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: faker in /usr/local/lib/python3.12/dist-packages (40.1.2)
# Collecting eth-abi>=5.0.1 (from web3)
#   Downloading eth_abi-5.2.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting eth-account>=0.13.6 (from web3)
#   Downloading eth_account-0.13.7-py3-none-any.whl.metadata (3.7 kB)
# Collecting eth-hash>=0.5.1 (from eth-hash[pycryptodome]>=0.5.1->web3)
#   Downloading eth_hash-0.7.1-py3-none-any.whl.metadata (4.2 kB)
# Collecting eth-typing>=5.0.0 (from web3)
#   Downloading eth_typing-5.2.1-py3-none-any.whl.metadata (3.2 kB)
# Collecting eth-utils>=5.0.0 (from web3)
#   Downloading eth_utils-5.3.1-py3-none-any.whl.metadata (5.7 kB)
# Collecting hexbytes>=1.2.0 (from web3)
#   Downloading hexbytes-1.3.1-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: aiohttp>=3.7.4.post0 in /usr/local/lib/python3.12/dist-packages (from web3) (3.13.3)
# Requirement already satisfied: pydantic>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from web3) (2.12.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from web3) (2.32.4)
# Requirement already satisfied: typing-extensions>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from web3) (4.15.0)
# Collecting types-requests>=2.0.0 (from web3)
#   Downloading types_requests-2.32.4.20260107-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: websockets<16.0.0,>=10.0.0 in /usr/local/lib/python3.12/dist-packages (from web3) (15.0.1)
# Collecting pyunormalize>=15.0.0 (from web3)
#   Downloading pyunormalize-17.0.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.7.4.post0->web3) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.7.4.post0->web3) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.7.4.post0->web3) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.7.4.post0->web3) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.7.4.post0->web3) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.7.4.post0->web3) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.7.4.post0->web3) (1.22.0)
# Collecting parsimonious<0.11.0,>=0.10.0 (from eth-abi>=5.0.1->web3)
#   Downloading parsimonious-0.10.0-py3-none-any.whl.metadata (25 kB)
# Collecting bitarray>=2.4.0 (from eth-account>=0.13.6->web3)
#   Downloading bitarray-3.8.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (34 kB)
# Collecting eth-abi>=5.0.1 (from web3)
#   Downloading eth_abi-6.0.0b1-py3-none-any.whl.metadata (3.8 kB)
# Collecting eth-keyfile<0.9.0,>=0.7.0 (from eth-account>=0.13.6->web3)
#   Downloading eth_keyfile-0.8.1-py3-none-any.whl.metadata (8.5 kB)
# Collecting eth-keys>=0.4.0 (from eth-account>=0.13.6->web3)
#   Downloading eth_keys-0.7.0-py3-none-any.whl.metadata (13 kB)
# Collecting eth-rlp>=2.1.0 (from eth-account>=0.13.6->web3)
#   Downloading eth_rlp-2.2.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting rlp>=1.0.0 (from eth-account>=0.13.6->web3)
#   Downloading rlp-4.1.0-py3-none-any.whl.metadata (3.2 kB)
# Collecting ckzg>=2.0.0 (from eth-account>=0.13.6->web3)
#   Downloading ckzg-2.1.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (887 bytes)
# Collecting pycryptodome<4,>=3.6.6 (from eth-hash[pycryptodome]>=0.5.1->web3)
#   Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Collecting cytoolz>=0.10.1 (from eth-utils>=5.0.0->web3)
#   Downloading cytoolz-1.1.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.4.0->web3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.4.0->web3) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.4.0->web3) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->web3) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->web3) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->web3) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->web3) (2026.1.4)
# Requirement already satisfied: toolz>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from cytoolz>=0.10.1->eth-utils>=5.0.0->web3) (0.12.1)
# Requirement already satisfied: regex>=2022.3.15 in /usr/local/lib/python3.12/dist-packages (from parsimonious<0.11.0,>=0.10.0->eth-abi>=5.0.1->web3) (2025.11.3)
# Downloading web3-7.14.0-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 22.9 MB/s eta 0:00:00
# Downloading eth_abi-5.2.0-py3-none-any.whl (28 kB)
# Downloading eth_account-0.13.7-py3-none-any.whl (587 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.5/587.5 kB 40.3 MB/s eta 0:00:00
# Downloading eth_hash-0.7.1-py3-none-any.whl (8.0 kB)
# Downloading eth_typing-5.2.1-py3-none-any.whl (19 kB)
# Downloading eth_utils-5.3.1-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.5/102.5 kB 8.7 MB/s eta 0:00:00
# Downloading hexbytes-1.3.1-py3-none-any.whl (5.1 kB)
# Downloading pyunormalize-17.0.0-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 kB 4.0 MB/s eta 0:00:00
# Downloading types_requests-2.32.4.20260107-py3-none-any.whl (20 kB)
# Downloading bitarray-3.8.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (340 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 340.3/340.3 kB 25.2 MB/s eta 0:00:00
# Downloading ckzg-2.1.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (175 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.8/175.8 kB 14.0 MB/s eta 0:00:00
# Downloading cytoolz-1.1.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 56.2 MB/s eta 0:00:00
# Downloading eth_keyfile-0.8.1-py3-none-any.whl (7.5 kB)
# Downloading eth_keys-0.7.0-py3-none-any.whl (20 kB)
# Downloading eth_rlp-2.2.0-py3-none-any.whl (4.4 kB)
# Downloading parsimonious-0.10.0-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 4.2 MB/s eta 0:00:00
# Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 71.3 MB/s eta 0:00:00
# Downloading rlp-4.1.0-py3-none-any.whl (19 kB)
# Installing collected packages: ckzg, bitarray, types-requests, pyunormalize, pycryptodome, parsimonious, hexbytes, eth-typing, eth-hash, cytoolz, eth-utils, rlp, eth-keys, eth-abi, eth-rlp, eth-keyfile, eth-account, web3
# Successfully installed bitarray-3.8.0 ckzg-2.1.5 cytoolz-1.1.0 eth-abi-5.2.0 eth-account-0.13.7 eth-hash-0.7.1 eth-keyfile-0.8.1 eth-keys-0.7.0 eth-rlp-2.2.0 eth-typing-5.2.1 eth-utils-5.3.1 hexbytes-1.3.1 parsimonious-0.10.0 pycryptodome-3.23.0 pyunormalize-17.0.0 rlp-4.1.0 types-requests-2.32.4.20260107 web3-7.14.0

# %%
# %%writefile BatchIdentityRegistry.sol
# // SPDX-License-Identifier: MIT
# pragma solidity ^0.8.0;
#
# contract BatchIdentityRegistry {
#     struct Identity {
#         string ipfsHash;
#         uint256 timestamp;
#     }
#     mapping(address => Identity) public registry;
#
#     function batchRegister(address[] memory _students, string[] memory _hashes) public {
#         for (uint256 i = 0; i < _students.length; i++) {
#             registry[_students[i]] = Identity(_hashes[i], block.timestamp);
#         }
#     }
# }
# Out:
# Writing BatchIdentityRegistry.sol

# %% [markdown]
# # **Bridge between python and solidity**

# %% [markdown]
# Here is the Python logic to process your 10,000 records in batches of 100:

# %%
from faker import Faker
import json

fake = Faker()
total_records = 20000
batch_size = 100

# 1. Generate the 20,000 records
students = []
hashes = []
for _ in range(total_records):
    students.append(fake.hexify(text='0x' + '^' * 40)) # Mock Wallet
    hashes.append(f"Qm{fake.sha256()[:44]}")          # Mock IPFS Hash

# 2. Function to process in batches (Explanation for your paper)
def process_batches(student_list, hash_list, size):
    for i in range(0, len(student_list), size):
        batch_students = student_list[i:i + size]
        batch_hashes = hash_list[i:i + size]

        # In a real scenario, you would call the smart contract here:
        # contract.functions.batchRegister(batch_students, batch_hashes).transact()

        print(f"Uploaded batch starting at index {i}... (Total: {i+size})")

process_batches(students, hashes, batch_size)
# Out:
# Uploaded batch starting at index 0... (Total: 100)
# Uploaded batch starting at index 100... (Total: 200)
# Uploaded batch starting at index 200... (Total: 300)
# Uploaded batch starting at index 300... (Total: 400)
# Uploaded batch starting at index 400... (Total: 500)
# Uploaded batch starting at index 500... (Total: 600)
# Uploaded batch starting at index 600... (Total: 700)
# Uploaded batch starting at index 700... (Total: 800)
# Uploaded batch starting at index 800... (Total: 900)
# Uploaded batch starting at index 900... (Total: 1000)
# Uploaded batch starting at index 1000... (Total: 1100)
# Uploaded batch starting at index 1100... (Total: 1200)
# Uploaded batch starting at index 1200... (Total: 1300)
# Uploaded batch starting at index 1300... (Total: 1400)
# Uploaded batch starting at index 1400... (Total: 1500)
# Uploaded batch starting at index 1500... (Total: 1600)
# Uploaded batch starting at index 1600... (Total: 1700)
# Uploaded batch starting at index 1700... (Total: 1800)
# Uploaded batch starting at index 1800... (Total: 1900)
# Uploaded batch starting at index 1900... (Total: 2000)
# Uploaded batch starting at index 2000... (Total: 2100)
# Uploaded batch starting at index 2100... (Total: 2200)
# Uploaded batch starting at index 2200... (Total: 2300)
# Uploaded batch starting at index 2300... (Total: 2400)
# Uploaded batch starting at index 2400... (Total: 2500)
# Uploaded batch starting at index 2500... (Total: 2600)
# Uploaded batch starting at index 2600... (Total: 2700)
# Uploaded batch starting at index 2700... (Total: 2800)
# Uploaded batch starting at index 2800... (Total: 2900)
# Uploaded batch starting at index 2900... (Total: 3000)
# Uploaded batch starting at index 3000... (Total: 3100)
# Uploaded batch starting at index 3100... (Total: 3200)
# Uploaded batch starting at index 3200... (Total: 3300)
# Uploaded batch starting at index 3300... (Total: 3400)
# Uploaded batch starting at index 3400... (Total: 3500)
# Uploaded batch starting at index 3500... (Total: 3600)
# Uploaded batch starting at index 3600... (Total: 3700)
# Uploaded batch starting at index 3700... (Total: 3800)
# Uploaded batch starting at index 3800... (Total: 3900)
# Uploaded batch starting at index 3900... (Total: 4000)
# Uploaded batch starting at index 4000... (Total: 4100)
# Uploaded batch starting at index 4100... (Total: 4200)
# Uploaded batch starting at index 4200... (Total: 4300)
# Uploaded batch starting at index 4300... (Total: 4400)
# Uploaded batch starting at index 4400... (Total: 4500)
# Uploaded batch starting at index 4500... (Total: 4600)
# Uploaded batch starting at index 4600... (Total: 4700)
# Uploaded batch starting at index 4700... (Total: 4800)
# Uploaded batch starting at index 4800... (Total: 4900)
# Uploaded batch starting at index 4900... (Total: 5000)
# Uploaded batch starting at index 5000... (Total: 5100)
# Uploaded batch starting at index 5100... (Total: 5200)
# Uploaded batch starting at index 5200... (Total: 5300)
# Uploaded batch starting at index 5300... (Total: 5400)
# Uploaded batch starting at index 5400... (Total: 5500)
# Uploaded batch starting at index 5500... (Total: 5600)
# Uploaded batch starting at index 5600... (Total: 5700)
# Uploaded batch starting at index 5700... (Total: 5800)
# Uploaded batch starting at index 5800... (Total: 5900)
# Uploaded batch starting at index 5900... (Total: 6000)
# Uploaded batch starting at index 6000... (Total: 6100)
# Uploaded batch starting at index 6100... (Total: 6200)
# Uploaded batch starting at index 6200... (Total: 6300)
# Uploaded batch starting at index 6300... (Total: 6400)
# Uploaded batch starting at index 6400... (Total: 6500)
# Uploaded batch starting at index 6500... (Total: 6600)
# Uploaded batch starting at index 6600... (Total: 6700)
# Uploaded batch starting at index 6700... (Total: 6800)
# Uploaded batch starting at index 6800... (Total: 6900)
# Uploaded batch starting at index 6900... (Total: 7000)
# Uploaded batch starting at index 7000... (Total: 7100)
# Uploaded batch starting at index 7100... (Total: 7200)
# Uploaded batch starting at index 7200... (Total: 7300)
# Uploaded batch starting at index 7300... (Total: 7400)
# Uploaded batch starting at index 7400... (Total: 7500)
# Uploaded batch starting at index 7500... (Total: 7600)
# Uploaded batch starting at index 7600... (Total: 7700)
# Uploaded batch starting at index 7700... (Total: 7800)
# Uploaded batch starting at index 7800... (Total: 7900)
# Uploaded batch starting at index 7900... (Total: 8000)
# Uploaded batch starting at index 8000... (Total: 8100)
# Uploaded batch starting at index 8100... (Total: 8200)
# Uploaded batch starting at index 8200... (Total: 8300)
# Uploaded batch starting at index 8300... (Total: 8400)
# Uploaded batch starting at index 8400... (Total: 8500)
# Uploaded batch starting at index 8500... (Total: 8600)
# Uploaded batch starting at index 8600... (Total: 8700)
# Uploaded batch starting at index 8700... (Total: 8800)
# Uploaded batch starting at index 8800... (Total: 8900)
# Uploaded batch starting at index 8900... (Total: 9000)
# Uploaded batch starting at index 9000... (Total: 9100)
# Uploaded batch starting at index 9100... (Total: 9200)
# Uploaded batch starting at index 9200... (Total: 9300)
# Uploaded batch starting at index 9300... (Total: 9400)
# Uploaded batch starting at index 9400... (Total: 9500)
# Uploaded batch starting at index 9500... (Total: 9600)
# Uploaded batch starting at index 9600... (Total: 9700)
# Uploaded batch starting at index 9700... (Total: 9800)
# Uploaded batch starting at index 9800... (Total: 9900)
# Uploaded batch starting at index 9900... (Total: 10000)
# Uploaded batch starting at index 10000... (Total: 10100)
# Uploaded batch starting at index 10100... (Total: 10200)
# Uploaded batch starting at index 10200... (Total: 10300)
# Uploaded batch starting at index 10300... (Total: 10400)
# Uploaded batch starting at index 10400... (Total: 10500)
# Uploaded batch starting at index 10500... (Total: 10600)
# Uploaded batch starting at index 10600... (Total: 10700)
# Uploaded batch starting at index 10700... (Total: 10800)
# Uploaded batch starting at index 10800... (Total: 10900)
# Uploaded batch starting at index 10900... (Total: 11000)
# Uploaded batch starting at index 11000... (Total: 11100)
# Uploaded batch starting at index 11100... (Total: 11200)
# Uploaded batch starting at index 11200... (Total: 11300)
# Uploaded batch starting at index 11300... (Total: 11400)
# Uploaded batch starting at index 11400... (Total: 11500)
# Uploaded batch starting at index 11500... (Total: 11600)
# Uploaded batch starting at index 11600... (Total: 11700)
# Uploaded batch starting at index 11700... (Total: 11800)
# Uploaded batch starting at index 11800... (Total: 11900)
# Uploaded batch starting at index 11900... (Total: 12000)
# Uploaded batch starting at index 12000... (Total: 12100)
# Uploaded batch starting at index 12100... (Total: 12200)
# Uploaded batch starting at index 12200... (Total: 12300)
# Uploaded batch starting at index 12300... (Total: 12400)
# Uploaded batch starting at index 12400... (Total: 12500)
# Uploaded batch starting at index 12500... (Total: 12600)
# Uploaded batch starting at index 12600... (Total: 12700)
# Uploaded batch starting at index 12700... (Total: 12800)
# Uploaded batch starting at index 12800... (Total: 12900)
# Uploaded batch starting at index 12900... (Total: 13000)
# Uploaded batch starting at index 13000... (Total: 13100)
# Uploaded batch starting at index 13100... (Total: 13200)
# Uploaded batch starting at index 13200... (Total: 13300)
# Uploaded batch starting at index 13300... (Total: 13400)
# Uploaded batch starting at index 13400... (Total: 13500)
# Uploaded batch starting at index 13500... (Total: 13600)
# Uploaded batch starting at index 13600... (Total: 13700)
# Uploaded batch starting at index 13700... (Total: 13800)
# Uploaded batch starting at index 13800... (Total: 13900)
# Uploaded batch starting at index 13900... (Total: 14000)
# Uploaded batch starting at index 14000... (Total: 14100)
# Uploaded batch starting at index 14100... (Total: 14200)
# Uploaded batch starting at index 14200... (Total: 14300)
# Uploaded batch starting at index 14300... (Total: 14400)
# Uploaded batch starting at index 14400... (Total: 14500)
# Uploaded batch starting at index 14500... (Total: 14600)
# Uploaded batch starting at index 14600... (Total: 14700)
# Uploaded batch starting at index 14700... (Total: 14800)
# Uploaded batch starting at index 14800... (Total: 14900)
# Uploaded batch starting at index 14900... (Total: 15000)
# Uploaded batch starting at index 15000... (Total: 15100)
# Uploaded batch starting at index 15100... (Total: 15200)
# Uploaded batch starting at index 15200... (Total: 15300)
# Uploaded batch starting at index 15300... (Total: 15400)
# Uploaded batch starting at index 15400... (Total: 15500)
# Uploaded batch starting at index 15500... (Total: 15600)
# Uploaded batch starting at index 15600... (Total: 15700)
# Uploaded batch starting at index 15700... (Total: 15800)
# Uploaded batch starting at index 15800... (Total: 15900)
# Uploaded batch starting at index 15900... (Total: 16000)
# Uploaded batch starting at index 16000... (Total: 16100)
# Uploaded batch starting at index 16100... (Total: 16200)
# Uploaded batch starting at index 16200... (Total: 16300)
# Uploaded batch starting at index 16300... (Total: 16400)
# Uploaded batch starting at index 16400... (Total: 16500)
# Uploaded batch starting at index 16500... (Total: 16600)
# Uploaded batch starting at index 16600... (Total: 16700)
# Uploaded batch starting at index 16700... (Total: 16800)
# Uploaded batch starting at index 16800... (Total: 16900)
# Uploaded batch starting at index 16900... (Total: 17000)
# Uploaded batch starting at index 17000... (Total: 17100)
# Uploaded batch starting at index 17100... (Total: 17200)
# Uploaded batch starting at index 17200... (Total: 17300)
# Uploaded batch starting at index 17300... (Total: 17400)
# Uploaded batch starting at index 17400... (Total: 17500)
# Uploaded batch starting at index 17500... (Total: 17600)
# Uploaded batch starting at index 17600... (Total: 17700)
# Uploaded batch starting at index 17700... (Total: 17800)
# Uploaded batch starting at index 17800... (Total: 17900)
# Uploaded batch starting at index 17900... (Total: 18000)
# Uploaded batch starting at index 18000... (Total: 18100)
# Uploaded batch starting at index 18100... (Total: 18200)
# Uploaded batch starting at index 18200... (Total: 18300)
# Uploaded batch starting at index 18300... (Total: 18400)
# Uploaded batch starting at index 18400... (Total: 18500)
# Uploaded batch starting at index 18500... (Total: 18600)
# Uploaded batch starting at index 18600... (Total: 18700)
# Uploaded batch starting at index 18700... (Total: 18800)
# Uploaded batch starting at index 18800... (Total: 18900)
# Uploaded batch starting at index 18900... (Total: 19000)
# Uploaded batch starting at index 19000... (Total: 19100)
# Uploaded batch starting at index 19100... (Total: 19200)
# Uploaded batch starting at index 19200... (Total: 19300)
# Uploaded batch starting at index 19300... (Total: 19400)
# Uploaded batch starting at index 19400... (Total: 19500)
# Uploaded batch starting at index 19500... (Total: 19600)
# Uploaded batch starting at index 19600... (Total: 19700)
# Uploaded batch starting at index 19700... (Total: 19800)
# Uploaded batch starting at index 19800... (Total: 19900)
# Uploaded batch starting at index 19900... (Total: 20000)

# %% [markdown]
# # **Connecting python to the provider**

# %% [markdown]
# # **Smart Contract**

# %%
# 1. Paste the address from the 'Deployed Contracts' section in Remix. This must be the actual hexadecimal address (e.g., 0x...) of your deployed contract, NOT an API key or project ID.
CONTRACT_ADDRESS = "0xd9145CCE52D386f254917e481eB44e9943F39138"
# 2. Paste the ABI from the 'Solidity Compiler' tab in Remix
import json
CONTRACT_ABI = json.loads('''[
	{
		"inputs": [
			{
				"internalType": "address[]",
				"name": "_students",
				"type": "address[]"
			},
			{
				"internalType": "string[]",
				"name": "_hashes",
				"type": "string[]"
			}
		],
		"name": "batchRegister",
		"outputs": [],
		"stateMutability": "nonpayable",
		"type": "function"
	},
	{
		"inputs": [
			{
				"internalType": "address",
				"name": "",
				"type": "address"
			}
		],
		"name": "registry",
		"outputs": [
			{
				"internalType": "string",
				"name": "ipfsHash",
				"type": "string"
			},
			{
				"internalType": "uint256",
				"name": "timestamp",
				"type": "uint256"
			}
		],
		"stateMutability": "view",
		"type": "function"
	}
]
''')

# 3. Now this line will work without a NameError
contract = w3.eth.contract(address=CONTRACT_ADDRESS, abi=CONTRACT_ABI)
